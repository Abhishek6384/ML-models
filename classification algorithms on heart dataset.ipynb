# %%
# Heart Attack Analysis  : - it will classify whether the person will have the Heart Attack based on age,sex,chestpain,resting blood pressure etc

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('heart.csv')

# %%
df.head(5)
# Out:
#    age  sex  Chest Pain  resting blood pressure  cholestoral  \
# 0   63    1           3                     145          233
# 1   37    1           2                     130          250
# 2   41    0           1                     130          204
# 3   56    1           1                     120          236
# 4   57    0           0                     120          354
#
#    fasting blood sugar  resting electrocardiographic  maximum heart rate  \
# 0                    1                             0                 150
# 1                    0                             1                 187
# 2                    0                             0                 172
# 3                    0                             1                 178
# 4                    0                             1                 163
#
#    exercise induced angina   oldpeak  slp  caa  thall  output
# 0                         0      2.3    0    0      1       1
# ...

# %%
df.describe()
# Out:
#               age         sex  Chest Pain  resting blood pressure  \
# count  303.000000  303.000000  303.000000              303.000000
# mean    54.366337    0.683168    0.966997              131.623762
# std      9.082101    0.466011    1.032052               17.538143
# min     29.000000    0.000000    0.000000               94.000000
# 25%     47.500000    0.000000    0.000000              120.000000
# 50%     55.000000    1.000000    1.000000              130.000000
# 75%     61.000000    1.000000    2.000000              140.000000
# max     77.000000    1.000000    3.000000              200.000000
#
#        cholestoral  fasting blood sugar  resting electrocardiographic  \
# count   303.000000           303.000000                    303.000000
# mean    246.264026             0.148515                      0.528053
# std      51.830751             0.356198                      0.525860
# min     126.000000             0.000000                      0.000000
# ...

# %%
df.isna().sum()
# Out:
# age                             0
# sex                             0
# Chest Pain                      0
# resting blood pressure          0
# cholestoral                     0
# fasting blood sugar             0
# resting electrocardiographic    0
# maximum heart rate              0
# exercise induced angina         0
# oldpeak                         0
# slp                             0
# caa                             0
# thall                           0
# output                          0
# dtype: int64

# %%
# dropping useless columns using drop function
new_df=df.drop(['slp','caa','thall'],axis=1)
new_df.head(5)
# Out:
#    age  sex  Chest Pain  resting blood pressure  cholestoral  \
# 0   63    1           3                     145          233
# 1   37    1           2                     130          250
# 2   41    0           1                     130          204
# 3   56    1           1                     120          236
# 4   57    0           0                     120          354
#
#    fasting blood sugar  resting electrocardiographic  maximum heart rate  \
# 0                    1                             0                 150
# 1                    0                             1                 187
# 2                    0                             0                 172
# 3                    0                             1                 178
# 4                    0                             1                 163
#
#    exercise induced angina   oldpeak  output
# 0                         0      2.3       1
# 1                         0      3.5       1
# ...

# %%
# visualization of the dataset using histogram
new_df.hist(figsize = (20,20))
plt.show()
